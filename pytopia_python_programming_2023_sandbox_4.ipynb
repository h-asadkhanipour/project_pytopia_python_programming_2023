# %% [markdown]
# ---
# ---
# ---
# # 10.Modular programming in python
# ---
# ---
# ---

# %% [markdown]
# # 01 Jupyter Notebook Limiations

# %% [markdown]
# # 02 Modular Programming

# %% [markdown]
# documentation
