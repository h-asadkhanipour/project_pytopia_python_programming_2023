# %% [markdown]
# test of jupyter
#
# new line can move with alt

# %%
print("hello ")

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("hello world!")
# Out:
# hello world!

# %%
test
